# %%
import ROOT

# %%
import uproot

# %%
infile_name = './Templates_SNOLAB_R4_zip1_1x1.root'

infile = uproot.open(infile_name)

# %%
keys = infile.keys()

print(keys)
# Out:
# ['zip1;1', 'zip1/PAS1;1', 'zip1/PBS1;1', 'zip1/PCS1;1', 'zip1/PES1;1', 'zip1/PFS1;1', 'zip1/PAS2;1', 'zip1/PCS2;1', 'zip1/PDS2;1', 'zip1/PES2;1', 'zip1/PT;1', 'zip1/PS1;1', 'zip1/PS2;1', 'zip1/PAS1nxm0;1', 'zip1/PAS1nxm1;1', 'zip1/PAS1nxm2;1', 'zip1/PAS1nxm3;1', 'zip1/PBS1nxm0;1', 'zip1/PBS1nxm1;1', 'zip1/PBS1nxm2;1', 'zip1/PBS1nxm3;1', 'zip1/PCS1nxm0;1', 'zip1/PCS1nxm1;1', 'zip1/PCS1nxm2;1', 'zip1/PCS1nxm3;1', 'zip1/PES1nxm0;1', 'zip1/PES1nxm1;1', 'zip1/PES1nxm2;1', 'zip1/PES1nxm3;1', 'zip1/PFS1nxm0;1', 'zip1/PFS1nxm1;1', 'zip1/PFS1nxm2;1', 'zip1/PFS1nxm3;1', 'zip1/PAS2nxm0;1', 'zip1/PAS2nxm1;1', 'zip1/PAS2nxm2;1', 'zip1/PAS2nxm3;1', 'zip1/PCS2nxm0;1', 'zip1/PCS2nxm1;1', 'zip1/PCS2nxm2;1', 'zip1/PCS2nxm3;1', 'zip1/PDS2nxm0;1', 'zip1/PDS2nxm1;1', 'zip1/PDS2nxm2;1', 'zip1/PDS2nxm3;1', 'zip1/PES2nxm0;1', 'zip1/PES2nxm1;1', 'zip1/PES2nxm2;1', 'zip1/PES2nxm3;1']

# %%
# %pip install hist
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
th1d_hist = infile["zip1/PAS1"]
    
th1d_hist.to_hist().plot()
# Out:
# /usr/local/lib/python3.12/dist-packages/mplhep/_utils.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   return values - np.sqrt(variances), values + np.sqrt(variances)
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f6863a8dc10>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
